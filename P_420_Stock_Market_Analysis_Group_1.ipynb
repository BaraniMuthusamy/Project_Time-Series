# %%
! pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.41)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.1.4)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.4)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.7.4)

# %%
import yfinance as yf
import pandas as pd

# Define the stock symbol and the date range
symbol = 'RELIANCE.NS'  # .NS is for NSE (National Stock Exchange of India)
start_date = '2014-07-01'
end_date = '2024-06-30'

# Fetch the stock data
data = yf.download(symbol, start=start_date, end=end_date)

# Find the day with the most traded quantity
most_traded_day = data['Volume'].idxmax()

# Get the prices for the day with the most traded quantity
most_traded_day_data = data.loc[most_traded_day]

# Create a new dataframe to store the information
most_traded_quantity_data = pd.DataFrame({
    'Date': [most_traded_day],
    'Open': [most_traded_day_data['Open']],
    'High': [most_traded_day_data['High']],
    'Low': [most_traded_day_data['Low']],
    'Close': [most_traded_day_data['Close']],
    'Volume': [most_traded_day_data['Volume']]
})

# Save to a CSV file
most_traded_quantity_data.to_csv('RELIANCE_most_traded_quantity_data.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2014-07-01   465.029633   466.561127   460.343658   460.823700   434.592499
# 2014-07-02   464.938171   469.669861   462.652344   465.509644   439.011688
# 2014-07-03   466.309692   468.595520   458.766449   460.137939   433.945770
# 2014-07-04   459.452179   473.990082   458.675018   471.772827   444.918396
# 2014-07-07   472.252838   474.081512   466.766846   469.601288   442.870422
# ...                 ...          ...          ...          ...          ...
# 2024-06-24  2891.050049  2899.000000  2875.000000  2882.949951  2882.949951
# 2024-06-25  2886.000000  2911.850098  2882.000000  2908.300049  2908.300049
# 2024-06-26  2892.100098  3037.949951  2890.250000  3028.050049  3028.050049
# 2024-06-27  3027.500000  3075.000000  3012.000000  3061.100098  3061.100098
# 2024-06-28  3062.050049  3162.000000  3062.050049  3130.800049  3130.800049
#
#               Volume
# Date
# 2014-07-01   4826636
# 2014-07-02   6146744
# 2014-07-03   5787696
# 2014-07-04   6478558
# 2014-07-07   7009546
# ...              ...
# 2024-06-24   4439193
# 2024-06-25   3522693
# 2024-06-26  11007441
# 2024-06-27  14191515
# 2024-06-28  14478668
#
# [2462 rows x 6 columns]

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the stock symbol and the date range
symbol = 'RELIANCE.NS'
start_date = '2014-07-01'
end_date = '2024-06-30'

# Fetch the stock data
data = yf.download(symbol, start=start_date, end=end_date)

# Display the first few rows of the data
print(data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-07-01  465.029633  466.561127  460.343658  460.823700  434.592499
# 2014-07-02  464.938171  469.669861  462.652344  465.509644  439.011688
# 2014-07-03  466.309692  468.595520  458.766449  460.137939  433.945770
# 2014-07-04  459.452179  473.990082  458.675018  471.772827  444.918396
# 2014-07-07  472.252838  474.081512  466.766846  469.601288  442.870422
#
#              Volume
# Date
# 2014-07-01  4826636
# 2014-07-02  6146744
# 2014-07-03  5787696
# 2014-07-04  6478558
# 2014-07-07  7009546

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2462 entries, 2014-07-01 to 2024-06-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2462 non-null   float64
#  1   High       2462 non-null   float64
#  2   Low        2462 non-null   float64
#  3   Close      2462 non-null   float64
#  4   Adj Close  2462 non-null   float64
#  5   Volume     2462 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 134.6 KB

# %%
data.describe().T
# Out:
#             count          mean           std         min           25%  \
# Open       2462.0  1.368969e+03  8.084943e+02  373.322052  4.894709e+02
# High       2462.0  1.383281e+03  8.160110e+02  373.824921  4.959912e+02
# Low        2462.0  1.353964e+03  8.006725e+02  364.110138  4.856535e+02
# Close      2462.0  1.368140e+03  8.082615e+02  370.647614  4.911738e+02
# Adj Close  2462.0  1.351416e+03  8.131487e+02  349.549438  4.736700e+02
# Volume     2462.0  9.206989e+06  6.760046e+06    0.000000  5.374693e+06
#
#                     50%           75%           max
# Open       1.171466e+03  2.191028e+03  3.062050e+03
# High       1.181501e+03  2.211265e+03  3.162000e+03
# Low        1.158688e+03  2.167273e+03  3.062050e+03
# Close      1.169020e+03  2.188744e+03  3.130800e+03
# Adj Close  1.147265e+03  2.177206e+03  3.130800e+03
# Volume     7.323024e+06  1.049637e+07  7.134168e+07

# %%
plt.figure(figsize=(14, 7))
plt.plot(data['Close'], label='Close Price')
plt.title('Close Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the stock symbol and the date range
symbol = 'RELIANCE.NS'
start_date = '2014-07-01'
end_date = '2024-06-30'

# Fetch the stock data
data = yf.download(symbol, start=start_date, end=end_date)

# Calculate the average of Open, Low, High, and Adj Close prices
data['Avg Price'] = data[['Open', 'Low', 'High', 'Adj Close']].mean(axis=1)

# Plot the average price
plt.figure(figsize=(14, 7))
plt.plot(data['Avg Price'], label='Average Price (Open, Low, High, Adj Close)')
plt.title('Average Price Over Time')
plt.xlabel('Date')
plt.ylabel('Average Price')
plt.legend()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data['20 Day MA'] = data['Avg Price'].rolling(window=20).mean()
data['50 Day MA'] = data['Avg Price'].rolling(window=50).mean()

plt.figure(figsize=(14, 7))
plt.plot(data['Avg Price'], label='Avg Price')
plt.plot(data['20 Day MA'], label='20 Day MA')
plt.plot(data['50 Day MA'], label='50 Day MA')
plt.title('Avg Price and Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14, 7))
plt.bar(data.index, data['Volume'], color='blue')
plt.title('Volume Traded Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Close'], bins=50, kde=True)
plt.title('Distribution of Closing Prices')
plt.xlabel('Close Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Avg Price'], bins=50, kde=True)
plt.title('Distribution of Avg Prices')
plt.xlabel('Avg Price')
plt.ylabel('Frequency')
plt.show()

# %%
fig, axs = plt.subplots(3, 2, figsize=(15, 15))
sns.histplot(data['Open'], kde=True, ax=axs[0, 0])
axs[0, 0].set_title('Distribution of Open Prices')

sns.histplot(data['High'], kde=True, ax=axs[0, 1])
axs[0, 1].set_title('Distribution of High Prices')

sns.histplot(data['Low'], kde=True, ax=axs[1, 0])
axs[1, 0].set_title('Distribution of Low Prices')

sns.histplot(data['Close'], kde=True, ax=axs[1, 1])
axs[1, 1].set_title('Distribution of Close Prices')

sns.histplot(data['Volume'], kde=True, ax=axs[2, 0])
axs[2, 0].set_title('Distribution of Volume')

# Hide the empty subplot
axs[2, 1].axis('off')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
# Drop NaN values to avoid issues in pairplot
data_clean = data.dropna(subset=['Avg Price', '20 Day MA', '50 Day MA'])

# Plot pairplot
sns.pairplot(data_clean[['Open', 'High', 'Low', 'Close', 'Volume', 'Avg Price', '20 Day MA', '50 Day MA']])
plt.suptitle('Pair Plot of Stock Features', y=1.02)
plt.show()

# %%
! pip install mplfinance
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.10b0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mplfinance) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mplfinance) (2.1.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mplfinance) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mplfinance) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Downloading mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 6.5 MB/s eta 0:00:00
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.10b0

# %%
import mplfinance as mpf

# Plot candlestick chart
mpf.plot(data, type='candle', style='charles', volume=True, title='Candlestick Chart')
# Out:
# /usr/local/lib/python3.10/dist-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the stock symbol and the date range
symbol = 'RELIANCE.NS'
start_date = '2014-07-01'
end_date = '2024-06-30'

# Fetch the stock data
data = yf.download(symbol, start=start_date, end=end_date)

# Calculate the average price (Open, Low, High, Adj Close)
data['Avg Price'] = data[['Open', 'Low', 'High', 'Adj Close']].mean(axis=1)

# Add a 'Year' column to the dataframe
data['Year'] = data.index.year

# Group by year and calculate the average price for each year
average_yearly_price = data.groupby('Year')['Avg Price'].mean()

# Convert the result to a DataFrame for easier handling
average_yearly_price_df = average_yearly_price.reset_index()

# Display the average yearly prices
print(average_yearly_price_df)

# Plot the average yearly stock price
plt.figure(figsize=(14, 7))
sns.barplot(x='Year', y='Avg Price', data=average_yearly_price_df, palette='viridis')
plt.title('Average Yearly Stock Price (2014-2024)')
plt.xlabel('Year')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <ipython-input-18-c4364f3f8e4c>:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Year', y='Avg Price', data=average_yearly_price_df, palette='viridis')
#     Year    Avg Price
# 0   2014   438.596291
# 1   2015   413.652250
# 2   2016   459.472843
# 3   2017   671.329983
# 4   2018   946.355078
# 5   2019  1203.936029
# 6   2020  1603.362965
# 7   2021  2027.577785
# 8   2022  2330.582898
# 9   2023  2329.608789
# 10  2024  2878.668124

# %% [markdown]
# ### Checking if the data is stationary

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def adf_test(series):
    result = adfuller(series, autolag='AIC')
    labels = ['ADF Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used']
    for value, label in zip(result, labels):
        print(f'{label}: {value}')
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary.")
    else:
        print("Weak evidence against the null hypothesis, fail to reject the null hypothesis. Data has a unit root and is non-stationary.")

# %%
# Perform ADF test on the average price
print("ADF Test for Average Price:")
adf_test(data['Avg Price'].dropna())
# Out:
# ADF Test for Average Price:
# ADF Test Statistic: 0.34879832198469585
# p-value: 0.9794758322506636
# #Lags Used: 2
# Number of Observations Used: 2459
# Weak evidence against the null hypothesis, fail to reject the null hypothesis. Data has a unit root and is non-stationary.

# %%
def adf_test(series):
    result = adfuller(series.dropna(), autolag='AIC')
    labels = ['ADF Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used']
    for value, label in zip(result, labels):
        print(f'{label}: {value}')
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary.")
    else:
        print("Weak evidence against the null hypothesis, fail to reject the null hypothesis. Data has a unit root and is non-stationary.")

print("ADF Test for Original Average Price:")
adf_test(data['Avg Price'])
# Out:
# ADF Test for Original Average Price:
# ADF Test Statistic: 0.34879832198469585
# p-value: 0.9794758322506636
# #Lags Used: 2
# Number of Observations Used: 2459
# Weak evidence against the null hypothesis, fail to reject the null hypothesis. Data has a unit root and is non-stationary.

# %%
# Function to plot rolling statistics
def plot_rolling_statistics(series, title='Rolling Mean & Standard Deviation'):
    plt.figure(figsize=(14, 7))
    plt.plot(series, color='blue', label='Original')
    plt.plot(series.rolling(window=12).mean(), color='red', label='Rolling Mean')
    plt.plot(series.rolling(window=12).std(), color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title(title)
    plt.show()

# %%
plot_rolling_statistics(data['Avg Price'], title='Rolling Mean & Standard Deviation of Average Price')

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
# Plot ACF and PACF
plt.figure(figsize=(14, 7))
plot_acf(data['Avg Price'].dropna(), lags=50)
plt.title('Autocorrelation Function (ACF)')
plt.show()

# %%
plt.figure(figsize=(14, 7))
plot_pacf(data['Avg Price'].dropna(), lags=50)
plt.title('Partial Autocorrelation Function (PACF)')
plt.show()

# %% [markdown]
# ------

# %% [markdown]
# ### With KPSS test

# %%
from statsmodels.tsa.stattools import adfuller, kpss

# %%
def kpss_test(series, **kw):
    statistic, p_value, n_lags, critical_values = kpss(series, **kw)
    print(f'KPSS Statistic: {statistic}')
    print(f'p-value: {p_value}')
    print(f'num lags: {n_lags}')
    print('Critical Values:')
    for key, value in critical_values.items():
        print(f'   {key} : {value}')
    if p_value < 0.05:
        print("Strong evidence against the null hypothesis, reject the null hypothesis. Data is not stationary.")
    else:
        print("Weak evidence against the null hypothesis, fail to reject the null hypothesis. Data is stationary.")

# Perform KPSS test on the average price
print("KPSS Test for Average Price:")
kpss_test(data['Avg Price'].dropna(), regression='c')
# Out:
# KPSS Test for Average Price:
# KPSS Statistic: 7.818756669746748
# p-value: 0.01
# num lags: 30
# Critical Values:
#    10% : 0.347
#    5% : 0.463
#    2.5% : 0.574
#    1% : 0.739
# Strong evidence against the null hypothesis, reject the null hypothesis. Data is not stationary.
# <ipython-input-29-7495ea735b70>:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   statistic, p_value, n_lags, critical_values = kpss(series, **kw)

# %% [markdown]
# ### Second attempt to De-trending the data

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
# Differencing
data['Differenced'] = data['Avg Price'].diff()

# Exponential Smoothing
exp_smoothed = ExponentialSmoothing(data['Avg Price'].dropna(), trend='additive', seasonal=None).fit()
data['Exp Smoothed'] = exp_smoothed.fittedvalues

# Function to perform ADF test
def adf_test(series):
    result = adfuller(series.dropna(), autolag='AIC')
    labels = ['ADF Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used']
    for value, label in zip(result, labels):
        print(f'{label}: {value}')
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary.")
    else:
        print("Weak evidence against the null hypothesis, fail to reject the null hypothesis. Data has a unit root and is non-stationary.")

# Function to perform KPSS test
def kpss_test(series, **kw):
    statistic, p_value, n_lags, critical_values = kpss(series.dropna(), **kw)
    print(f'KPSS Statistic: {statistic}')
    print(f'p-value: {p_value}')
    print(f'num lags: {n_lags}')
    print('Critical Values:')
    for key, value in critical_values.items():
        print(f'   {key} : {value}')
    if p_value < 0.05:
        print("Strong evidence against the null hypothesis, reject the null hypothesis. Data is not stationary.")
    else:
        print("Weak evidence against the null hypothesis, fail to reject the null hypothesis. Data is stationary.")

# Perform ADF and KPSS tests on the original and de-trended data
print("ADF Test for Original Average Price:")
adf_test(data['Avg Price'])
print("\nKPSS Test for Original Average Price:")
kpss_test(data['Avg Price'], regression='c')

print("\nADF Test for Differenced Price:")
adf_test(data['Differenced'])
print("\nKPSS Test for Differenced Price:")
kpss_test(data['Differenced'], regression='c')

print("\nADF Test for Exponentially Smoothed Price:")
adf_test(data['Exp Smoothed'])
print("\nKPSS Test for Exponentially Smoothed Price:")
kpss_test(data['Exp Smoothed'], regression='c')
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ADF Test for Original Average Price:
# ADF Test Statistic: 0.34879832198469585
# p-value: 0.9794758322506636
# #Lags Used: 2
# Number of Observations Used: 2459
# Weak evidence against the null hypothesis, fail to reject the null hypothesis. Data has a unit root and is non-stationary.
#
# KPSS Test for Original Average Price:
# <ipython-input-31-4fd1fcf7c5b4>:21: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   statistic, p_value, n_lags, critical_values = kpss(series.dropna(), **kw)
# KPSS Statistic: 7.818756669746748
# p-value: 0.01
# num lags: 30
# Critical Values:
#    10% : 0.347
#    5% : 0.463
#    2.5% : 0.574
#    1% : 0.739
# Strong evidence against the null hypothesis, reject the null hypothesis. Data is not stationary.
#
# ADF Test for Differenced Price:
# ADF Test Statistic: -32.554249748991765
# p-value: 0.0
# #Lags Used: 1
# Number of Observations Used: 2459
# Strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary.
#
# KPSS Test for Differenced Price:
# KPSS Statistic: 0.1489643571343902
# p-value: 0.1
# num lags: 2
# Critical Values:
#    10% : 0.347
#    5% : 0.463
#    2.5% : 0.574
#    1% : 0.739
# Weak evidence against the null hypothesis, fail to reject the null hypothesis. Data is stationary.
#
# ADF Test for Exponentially Smoothed Price:
# <ipython-input-31-4fd1fcf7c5b4>:21: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   statistic, p_value, n_lags, critical_values = kpss(series.dropna(), **kw)
# ADF Test Statistic: 0.1945528882638396
# p-value: 0.971954421875372
# #Lags Used: 19
# Number of Observations Used: 2442
# Weak evidence against the null hypothesis, fail to reject the null hypothesis. Data has a unit root and is non-stationary.
#
# KPSS Test for Exponentially Smoothed Price:
# KPSS Statistic: 7.813824129089117
# p-value: 0.01
# num lags: 30
# Critical Values:
#    10% : 0.347
#    5% : 0.463
#    2.5% : 0.574
#    1% : 0.739
# Strong evidence against the null hypothesis, reject the null hypothesis. Data is not stationary.
# <ipython-input-31-4fd1fcf7c5b4>:21: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   statistic, p_value, n_lags, critical_values = kpss(series.dropna(), **kw)

# %%
# Plot the original, differenced, and exponentially smoothed series
plt.figure(figsize=(14, 7))
plt.plot(data['Avg Price'], label='Original')
plt.plot(data['Differenced'], label='Differenced', linestyle='--')
plt.plot(data['Exp Smoothed'], label='Exponentially Smoothed', linestyle='--')
plt.legend(loc='best')
plt.title('Original, Differenced, and Exponentially Smoothed Series')
plt.show()

# %%
# Plot ACF and PACF for the differenced series
plt.figure(figsize=(14, 7))
plot_acf(data['Differenced'].dropna(), lags=50)
plt.title('Autocorrelation Function (ACF) for Differenced Series')
plt.show()

# %%
plt.figure(figsize=(14, 7))
plot_pacf(data['Differenced'].dropna(), lags=50)
plt.title('Partial Autocorrelation Function (PACF) for Differenced Series')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Using ARIMA

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.model_selection import train_test_split

# %%
# Split data into training and testing sets using train_test_split
train, test = train_test_split(data['Differenced'].dropna(), test_size=0.2, shuffle=False)

# Fit ARIMA model
arima_model = ARIMA(train, order=(1, 1, 1))  # Order (p, d, q) needs to be tuned
arima_fitted_model = arima_model.fit()

# Make predictions with ARIMA
arima_predictions = arima_fitted_model.forecast(steps=len(test))
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
# Fit SARIMAX model
sarimax_model = SARIMAX(train, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))  # Seasonal order (p, d, q, s) needs to be tuned
sarimax_fitted_model = sarimax_model.fit()

# Make predictions with SARIMAX
sarimax_predictions = sarimax_fitted_model.forecast(steps=len(test))
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
# Print model summaries
print("ARIMA Model Summary:")
print(arima_fitted_model.summary())

print("\nSARIMAX Model Summary:")
print(sarimax_fitted_model.summary())
# Out:
# ARIMA Model Summary:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            Differenced   No. Observations:                 1968
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -8397.931
# Date:                Thu, 15 Aug 2024   AIC                          16801.863
# Time:                        06:19:41   BIC                          16818.615
# Sample:                             0   HQIC                         16808.019
#                                - 1968
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3605      0.013     28.409      0.000       0.336       0.385
# ma.L1         -0.9999      0.021    -47.553      0.000      -1.041      -0.959
# sigma2       298.1258      7.378     40.408      0.000     283.666     312.586
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.93   Jarque-Bera (JB):              4221.21
# Prob(Q):                              0.05   Prob(JB):                         0.00
# Heteroskedasticity (H):              32.81   Skew:                             0.29
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# SARIMAX Model Summary:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                        Differenced   No. Observations:                 1968
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood               -8380.666
# Date:                            Thu, 15 Aug 2024   AIC                          16771.331
# Time:                                    06:19:41   BIC                          16799.222
# Sample:                                         0   HQIC                         16781.584
#                                            - 1968
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3624      0.014     26.769      0.000       0.336       0.389
# ma.L1         -0.9996      0.019    -53.324      0.000      -1.036      -0.963
# ar.S.L12       0.0326      0.015      2.191      0.028       0.003       0.062
# ma.S.L12      -0.9997      0.171     -5.854      0.000      -1.334      -0.665
# sigma2       298.2643     49.855      5.983      0.000     200.551     395.978
# ===================================================================================
# Ljung-Box (L1) (Q):                   4.37   Jarque-Bera (JB):              4046.72
# Prob(Q):                              0.04   Prob(JB):                         0.00
# Heteroskedasticity (H):              32.90   Skew:                             0.29
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Define the stock symbol and the date range
symbol = 'RELIANCE.NS'
start_date = '2014-07-01'
end_date = '2024-06-30'

# Fetch the stock data
data = yf.download(symbol, start=start_date, end=end_date)

# Calculate the average price (Open, Low, High, Adj Close)
data['Avg Price'] = data[['Open', 'Low', 'High', 'Adj Close']].mean(axis=1)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# Differencing to remove trend
data['Differenced'] = data['Avg Price'].diff().dropna()

# Split data into training and testing sets using train_test_split
train, test = train_test_split(data['Differenced'].dropna(), test_size=0.2, shuffle=False)

# Fit ARIMA model
arima_model = ARIMA(train, order=(1, 1, 1))  # Order (p, d, q) needs to be tuned
arima_fitted_model = arima_model.fit()

# Make predictions with ARIMA
arima_predictions = arima_fitted_model.forecast(steps=len(test))

# Fit SARIMAX model
sarimax_model = SARIMAX(train, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))  # Seasonal order (p, d, q, s) needs to be tuned
sarimax_fitted_model = sarimax_model.fit()

# Make predictions with SARIMAX
sarimax_predictions = sarimax_fitted_model.forecast(steps=len(test))

# Calculate evaluation metrics
arima_mae = mean_absolute_error(test, arima_predictions)
arima_mse = mean_squared_error(test, arima_predictions)
arima_rmse = np.sqrt(arima_mse)

sarimax_mae = mean_absolute_error(test, sarimax_predictions)
sarimax_mse = mean_squared_error(test, sarimax_predictions)
sarimax_rmse = np.sqrt(sarimax_mse)

print(f"ARIMA Model - MAE: {arima_mae}, MSE: {arima_mse}, RMSE: {arima_rmse}")
print(f"SARIMAX Model - MAE: {sarimax_mae}, MSE: {sarimax_mse}, RMSE: {sarimax_rmse}")
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ARIMA Model - MAE: 18.834477173411145, MSE: 640.475919594576, RMSE: 25.30762572021674
# SARIMAX Model - MAE: 18.87141582472479, MSE: 636.9121000408857, RMSE: 25.237117506579185
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
# Prepare data for plotting
train_end = train.index[-1]
test_end = test.index[-1]

# %% [markdown]
# ----

# %% [markdown]
# ### ARIMA, SARIMAX and Winter-Holtz

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Define the stock symbol and the date range
symbol = 'RELIANCE.NS'
start_date = '2014-07-01'
end_date = '2024-06-30'

# Fetch the stock data
data = yf.download(symbol, start=start_date, end=end_date)

# Calculate the average price (Open, Low, High, Adj Close)
data['Avg Price'] = data[['Open', 'Low', 'High', 'Adj Close']].mean(axis=1)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# Differencing to remove trend
data['Differenced'] = data['Avg Price'].diff().dropna()

# Drop NA values created by differencing for proper split
data = data.dropna(subset=['Differenced'])

# Split data into training and testing sets
train, test = train_test_split(data['Differenced'], test_size=0.2, shuffle=False)

# %%
# Fit ARIMA model
arima_model = ARIMA(train, order=(1, 1, 1))  # Order (p, d, q) needs to be tuned
arima_fitted_model = arima_model.fit()

# Make predictions with ARIMA
arima_predictions = arima_fitted_model.forecast(steps=len(test))

# Forecast the next 30 days with ARIMA
arima_future_predictions = arima_fitted_model.get_forecast(steps=30)
arima_future_conf_int = arima_future_predictions.conf_int()
arima_future_dates = pd.date_range(start=data.index[-1] + pd.Timedelta(days=1), periods=30, freq='D')

# Fit SARIMAX model
sarimax_model = SARIMAX(train, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))  # Seasonal order (p, d, q, s) needs to be tuned
sarimax_fitted_model = sarimax_model.fit()

# Make predictions with SARIMAX
sarimax_predictions = sarimax_fitted_model.forecast(steps=len(test))

# Forecast the next 30 days with SARIMAX
sarimax_future_predictions = sarimax_fitted_model.get_forecast(steps=30)
sarimax_future_conf_int = sarimax_future_predictions.conf_int()
sarimax_future_dates = pd.date_range(start=data.index[-1] + pd.Timedelta(days=1), periods=30, freq='D')

# Fit Holt-Winters model
holt_winters_model = ExponentialSmoothing(train, trend='add', seasonal='add', seasonal_periods=12)  # Adjust parameters as needed
holt_winters_fitted_model = holt_winters_model.fit()

# Make predictions with Holt-Winters
holt_winters_predictions = holt_winters_fitted_model.forecast(steps=len(test))

# Forecast the next 30 days with Holt-Winters
holt_winters_future_predictions = holt_winters_fitted_model.forecast(steps=30)
holt_winters_future_dates = pd.date_range(start=data.index[-1] + pd.Timedelta(days=1), periods=30, freq='D')
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
# Calculate evaluation metrics
arima_mae = mean_absolute_error(test, arima_predictions)
arima_mse = mean_squared_error(test, arima_predictions)
arima_rmse = np.sqrt(arima_mse)

sarimax_mae = mean_absolute_error(test, sarimax_predictions)
sarimax_mse = mean_squared_error(test, sarimax_predictions)
sarimax_rmse = np.sqrt(sarimax_mse)

holt_winters_mae = mean_absolute_error(test, holt_winters_predictions)
holt_winters_mse = mean_squared_error(test, holt_winters_predictions)
holt_winters_rmse = np.sqrt(holt_winters_mse)

print(f"ARIMA Model - MAE: {arima_mae}, MSE: {arima_mse}, RMSE: {arima_rmse}")
print(f"SARIMAX Model - MAE: {sarimax_mae}, MSE: {sarimax_mse}, RMSE: {sarimax_rmse}")
print(f"Holt-Winters Model - MAE: {holt_winters_mae}, MSE: {holt_winters_mse}, RMSE: {holt_winters_rmse}")
# Out:
# ARIMA Model - MAE: 18.834477173411145, MSE: 640.475919594576, RMSE: 25.30762572021674
# SARIMAX Model - MAE: 18.87141582472479, MSE: 636.9121000408857, RMSE: 25.237117506579185
# Holt-Winters Model - MAE: 22.709527261958936, MSE: 902.313930876206, RMSE: 30.038540758102847

# %% [markdown]
# ---

# %% [markdown]
# ----

# %% [markdown]
# ## Predictions- Charts and numbers

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Define the stock symbol and the date range
symbol = 'RELIANCE.NS'
start_date = '2014-07-01'
end_date = '2024-06-30'

# Fetch the stock data
data = yf.download(symbol, start=start_date, end=end_date)

# Calculate the average price (Open, Low, High, Adj Close)
data['Avg Price'] = data[['Open', 'Low', 'High', 'Adj Close']].mean(axis=1)

# Differencing to remove trend
data['Differenced'] = data['Avg Price'].diff()
data.dropna(subset=['Differenced'], inplace=True)  # Drop NA values created by differencing

# Split data into training and testing sets
train_size = int(len(data) * 0.8)
train = data['Avg Price'][:train_size]
test = data['Avg Price'][train_size:]

# Fit ARIMA model
arima_model = ARIMA(train, order=(1, 1, 1))  # Order (p, d, q) needs to be tuned
arima_fitted_model = arima_model.fit()

# Make predictions with ARIMA
arima_predictions = arima_fitted_model.forecast(steps=len(test))

# Fit SARIMAX model
sarimax_model = SARIMAX(train, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))  # Seasonal order (p, d, q, s) needs to be tuned
sarimax_fitted_model = sarimax_model.fit()

# Make predictions with SARIMAX
sarimax_predictions = sarimax_fitted_model.forecast(steps=len(test))

# Fit Holt-Winters model
holt_winters_model = ExponentialSmoothing(train, trend='add', seasonal='add', seasonal_periods=12)
holt_winters_fitted_model = holt_winters_model.fit()

# Make predictions with Holt-Winters
holt_winters_predictions = holt_winters_fitted_model.forecast(steps=len(test))

# Calculate evaluation metrics
arima_mae = mean_absolute_error(test, arima_predictions)
arima_mse = mean_squared_error(test, arima_predictions)
arima_rmse = np.sqrt(arima_mse)

sarimax_mae = mean_absolute_error(test, sarimax_predictions)
sarimax_mse = mean_squared_error(test, sarimax_predictions)
sarimax_rmse = np.sqrt(sarimax_mse)

holt_winters_mae = mean_absolute_error(test, holt_winters_predictions)
holt_winters_mse = mean_squared_error(test, holt_winters_predictions)
holt_winters_rmse = np.sqrt(holt_winters_mse)

print(f"ARIMA Model - MAE: {arima_mae}, MSE: {arima_mse}, RMSE: {arima_rmse}")
print(f"SARIMAX Model - MAE: {sarimax_mae}, MSE: {sarimax_mse}, RMSE: {sarimax_rmse}")
print(f"Holt-Winters Model - MAE: {holt_winters_mae}, MSE: {holt_winters_mse}, RMSE: {holt_winters_rmse}")

# Future prediction
future_steps = 30
future_dates = pd.date_range(start=data.index[-1] + pd.Timedelta(days=1), periods=future_steps, freq='B')  # 'B' for business days

# Forecast future values with ARIMA, SARIMAX, and Holt-Winters models
arima_future = arima_fitted_model.forecast(steps=future_steps)
sarimax_future = sarimax_fitted_model.forecast(steps=future_steps)
holt_winters_future = holt_winters_fitted_model.forecast(steps=future_steps)

# Plot the results
plt.figure(figsize=(14, 7))

# Historical data
plt.plot(data.index, data['Avg Price'], label='Historical Data')

# Test data
plt.plot(test.index, test, label='Test Data', color='blue')

# ARIMA Predictions
plt.plot(test.index, arima_predictions, label='ARIMA Predictions', color='red')

# SARIMAX Predictions
plt.plot(test.index, sarimax_predictions, label='SARIMAX Predictions', color='green')

# Holt-Winters Predictions
plt.plot(test.index, holt_winters_predictions, label='Holt-Winters Predictions', color='purple')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ARIMA Model - MAE: 208.67520920981357, MSE: 87964.07176621087, RMSE: 296.58737627588073
# SARIMAX Model - MAE: 169.4635011773319, MSE: 40129.03622719815, RMSE: 200.32233082509336
# Holt-Winters Model - MAE: 179.42413876356338, MSE: 47549.50368407413, RMSE: 218.05848684257654
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# Future Predictions
plt.plot(future_dates, arima_future, label='ARIMA Future Predictions', color='orange', linestyle='--')
plt.plot(future_dates, sarimax_future, label='SARIMAX Future Predictions', color='cyan', linestyle='--')
plt.plot(future_dates, holt_winters_future, label='Holt-Winters Future Predictions', color='magenta', linestyle='--')

plt.legend(loc='best')
plt.title('ARIMA, SARIMAX, and Holt-Winters Model Predictions')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
# Create DataFrames for future predictions
future_df = pd.DataFrame({
    'Date': future_dates,
    'ARIMA Predictions': arima_future,
    'SARIMAX Predictions': sarimax_future,
    'Holt-Winters Predictions': holt_winters_future
})

print("Future 30 Days Predictions:")
print(future_df)

# Plot the results
plt.figure(figsize=(14, 7))

# Historical data
plt.plot(data.index, data['Avg Price'], label='Historical Data')

# Test data
plt.plot(test.index, test, label='Test Data', color='blue')

# ARIMA Predictions
plt.plot(test.index, arima_predictions, label='ARIMA Predictions', color='red')

# SARIMAX Predictions
plt.plot(test.index, sarimax_predictions, label='SARIMAX Predictions', color='green')

# Holt-Winters Predictions
plt.plot(test.index, holt_winters_predictions, label='Holt-Winters Predictions', color='purple')

# Future Predictions
plt.plot(future_dates, arima_future, label='ARIMA Future Predictions', color='orange', linestyle='--')
plt.plot(future_dates, sarimax_future, label='SARIMAX Future Predictions', color='cyan', linestyle='--')
plt.plot(future_dates, holt_winters_future, label='Holt-Winters Future Predictions', color='magenta', linestyle='--')

plt.legend(loc='best')
plt.title('ARIMA, SARIMAX, and Holt-Winters Model Predictions')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
# Out:
# Future 30 Days Predictions:
#            Date  ARIMA Predictions  SARIMAX Predictions  \
# 1968 2024-07-01        2326.495368          2327.672261
# 1969 2024-07-02        2326.823310          2323.207735
# 1970 2024-07-03        2326.836597          2324.406910
# 1971 2024-07-04        2326.837136          2322.699843
# 1972 2024-07-05        2326.837157          2321.074149
# 1973 2024-07-08        2326.837158          2320.289063
# 1974 2024-07-09        2326.837158          2321.574059
# 1975 2024-07-10        2326.837158          2323.601582
# 1976 2024-07-11        2326.837158          2322.910218
# 1977 2024-07-12        2326.837158          2323.571656
# 1978 2024-07-15        2326.837158          2324.990519
# 1979 2024-07-16        2326.837158          2326.637302
# 1980 2024-07-17        2326.837158          2329.197554
# 1981 2024-07-18        2326.837158          2328.425121
# 1982 2024-07-19        2326.837158          2330.097005
# 1983 2024-07-22        2326.837158          2329.715872
# 1984 2024-07-23        2326.837158          2328.445274
# 1985 2024-07-24        2326.837158          2328.342629
# 1986 2024-07-25        2326.837158          2330.178330
# 1987 2024-07-26        2326.837158          2332.531244
# 1988 2024-07-29        2326.837158          2333.375346
# 1989 2024-07-30        2326.837158          2335.972649
# 1990 2024-07-31        2326.837158          2337.362142
# 1991 2024-08-01        2326.837158          2337.928897
# 1992 2024-08-02        2326.837158          2340.168539
# 1993 2024-08-05        2326.837158          2339.572508
# 1994 2024-08-06        2326.837158          2341.266977
# 1995 2024-08-07        2326.837158          2340.949194
# 1996 2024-08-08        2326.837158          2339.695563
# 1997 2024-08-09        2326.837158          2339.625523
#
#       Holt-Winters Predictions
# 1968               2320.223520
# 1969               2318.774660
# 1970               2322.111020
# 1971               2322.628708
# 1972               2322.517661
# 1973               2324.444265
# 1974               2328.188480
# 1975               2330.704896
# 1976               2330.189753
# 1977               2332.997168
# 1978               2332.324509
# 1979               2331.636900
# 1980               2333.651780
# 1981               2332.202920
# 1982               2335.539281
# 1983               2336.056969
# 1984               2335.945922
# 1985               2337.872525
# 1986               2341.616740
# 1987               2344.133156
# 1988               2343.618014
# 1989               2346.425428
# 1990               2345.752769
# 1991               2345.065161
# 1992               2347.080040
# 1993               2345.631180
# 1994               2348.967541
# 1995               2349.485229
# 1996               2349.374182
# 1997               2351.300786

# %% [markdown]
# ---

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Define the stock symbol and the date range
symbol = 'RELIANCE.NS'
start_date = '2014-07-01'
end_date = '2024-06-30'

# Fetch the stock data
data = yf.download(symbol, start=start_date, end=end_date)

# Calculate the average price (Open, Low, High, Adj Close)
data['Avg Price'] = data[['Open', 'Low', 'High', 'Adj Close']].mean(axis=1)

# Differencing to remove trend
data['Differenced'] = data['Avg Price'].diff().dropna()

# Drop NA values created by differencing for proper split
data = data.dropna(subset=['Differenced'])

# Split data into training and testing sets
train_size = int(len(data) * 0.8)
train = data['Avg Price'][:train_size]
test = data['Avg Price'][train_size:]

# Fit ARIMA model
arima_model = ARIMA(train, order=(1, 1, 1))  # Order (p, d, q) needs to be tuned
arima_fitted_model = arima_model.fit()

# Make predictions with ARIMA
arima_predictions = arima_fitted_model.forecast(steps=len(test))

# Fit SARIMAX model
sarimax_model = SARIMAX(train, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))  # Seasonal order (p, d, q, s) needs to be tuned
sarimax_fitted_model = sarimax_model.fit()

# Make predictions with SARIMAX
sarimax_predictions = sarimax_fitted_model.forecast(steps=len(test))

# Fit Holt-Winters model
holt_winters_model = ExponentialSmoothing(train, trend='add', seasonal='add', seasonal_periods=12)
holt_winters_fitted_model = holt_winters_model.fit()

# Make predictions with Holt-Winters
holt_winters_predictions = holt_winters_fitted_model.forecast(steps=len(test))

# Calculate evaluation metrics
arima_mae = mean_absolute_error(test, arima_predictions)
arima_mse = mean_squared_error(test, arima_predictions)
arima_rmse = np.sqrt(arima_mse)

sarimax_mae = mean_absolute_error(test, sarimax_predictions)
sarimax_mse = mean_squared_error(test, sarimax_predictions)
sarimax_rmse = np.sqrt(sarimax_mse)

holt_winters_mae = mean_absolute_error(test, holt_winters_predictions)
holt_winters_mse = mean_squared_error(test, holt_winters_predictions)
holt_winters_rmse = np.sqrt(holt_winters_mse)

print(f"ARIMA Model - MAE: {arima_mae}, MSE: {arima_mse}, RMSE: {arima_rmse}")
print(f"SARIMAX Model - MAE: {sarimax_mae}, MSE: {sarimax_mse}, RMSE: {sarimax_rmse}")
print(f"Holt-Winters Model - MAE: {holt_winters_mae}, MSE: {holt_winters_mse}, RMSE: {holt_winters_rmse}")

# Future prediction
future_steps = 30
future_dates = pd.date_range(start='2024-07-01', periods=future_steps, freq='B')  # 'B' for business days

# Forecast future values with ARIMA, SARIMAX, and Holt-Winters models
arima_future = arima_fitted_model.forecast(steps=future_steps)
sarimax_future = sarimax_fitted_model.forecast(steps=future_steps)
holt_winters_future = holt_winters_fitted_model.forecast(steps=future_steps)

# Create DataFrames for future predictions
future_df = pd.DataFrame({
    'Date': future_dates,
    'ARIMA Predictions': arima_future,
    'SARIMAX Predictions': sarimax_future,
    'Holt-Winters Predictions': holt_winters_future
})

print("Future 30 Days Predictions:")
print(future_df)

# Plot the results
plt.figure(figsize=(14, 7))

# Historical data
plt.plot(data.index, data['Avg Price'], label='Historical Data')

# Test data
plt.plot(test.index, test, label='Test Data', color='blue')

# ARIMA Predictions
plt.plot(test.index, arima_predictions, label='ARIMA Predictions', color='red')

# SARIMAX Predictions
plt.plot(test.index, sarimax_predictions, label='SARIMAX Predictions', color='green')

# Holt-Winters Predictions
plt.plot(test.index, holt_winters_predictions, label='Holt-Winters Predictions', color='purple')

# Future Predictions
plt.plot(future_dates, arima_future, label='ARIMA Future Predictions', color='orange', linestyle='--')
plt.plot(future_dates, sarimax_future, label='SARIMAX Future Predictions', color='cyan', linestyle='--')
plt.plot(future_dates, holt_winters_future, label='Holt-Winters Future Predictions', color='magenta', linestyle='--')

plt.legend(loc='best')
plt.title('ARIMA, SARIMAX, and Holt-Winters Model Predictions')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# ARIMA Model - MAE: 208.67520920981357, MSE: 87964.07176621087, RMSE: 296.58737627588073
# SARIMAX Model - MAE: 169.4635011773319, MSE: 40129.03622719815, RMSE: 200.32233082509336
# Holt-Winters Model - MAE: 179.42413876356338, MSE: 47549.50368407413, RMSE: 218.05848684257654
# Future 30 Days Predictions:
#            Date  ARIMA Predictions  SARIMAX Predictions  \
# 1968 2024-07-01        2326.495368          2327.672261
# 1969 2024-07-02        2326.823310          2323.207735
# 1970 2024-07-03        2326.836597          2324.406910
# 1971 2024-07-04        2326.837136          2322.699843
# 1972 2024-07-05        2326.837157          2321.074149
# 1973 2024-07-08        2326.837158          2320.289063
# 1974 2024-07-09        2326.837158          2321.574059
# 1975 2024-07-10        2326.837158          2323.601582
# 1976 2024-07-11        2326.837158          2322.910218
# 1977 2024-07-12        2326.837158          2323.571656
# 1978 2024-07-15        2326.837158          2324.990519
# 1979 2024-07-16        2326.837158          2326.637302
# 1980 2024-07-17        2326.837158          2329.197554
# 1981 2024-07-18        2326.837158          2328.425121
# 1982 2024-07-19        2326.837158          2330.097005
# 1983 2024-07-22        2326.837158          2329.715872
# 1984 2024-07-23        2326.837158          2328.445274
# 1985 2024-07-24        2326.837158          2328.342629
# 1986 2024-07-25        2326.837158          2330.178330
# 1987 2024-07-26        2326.837158          2332.531244
# 1988 2024-07-29        2326.837158          2333.375346
# 1989 2024-07-30        2326.837158          2335.972649
# 1990 2024-07-31        2326.837158          2337.362142
# 1991 2024-08-01        2326.837158          2337.928897
# 1992 2024-08-02        2326.837158          2340.168539
# 1993 2024-08-05        2326.837158          2339.572508
# 1994 2024-08-06        2326.837158          2341.266977
# 1995 2024-08-07        2326.837158          2340.949194
# 1996 2024-08-08        2326.837158          2339.695563
# 1997 2024-08-09        2326.837158          2339.625523
#
#       Holt-Winters Predictions
# 1968               2320.223520
# 1969               2318.774660
# 1970               2322.111020
# 1971               2322.628708
# 1972               2322.517661
# 1973               2324.444265
# 1974               2328.188480
# 1975               2330.704896
# 1976               2330.189753
# 1977               2332.997168
# 1978               2332.324509
# 1979               2331.636900
# 1980               2333.651780
# 1981               2332.202920
# 1982               2335.539281
# 1983               2336.056969
# 1984               2335.945922
# 1985               2337.872525
# 1986               2341.616740
# 1987               2344.133156
# 1988               2343.618014
# 1989               2346.425428
# 1990               2345.752769
# 1991               2345.065161
# 1992               2347.080040
# 1993               2345.631180
# 1994               2348.967541
# 1995               2349.485229
# 1996               2349.374182
# 1997               2351.300786

# %%
# !pip install streamlit -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 88.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 94.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.3 MB/s eta 0:00:00

# %%
import streamlit as st
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Custom CSS for background image
css = """
<style>
body {
    background-image: url('download.jfif');
    background-size: cover;
    background-attachment: fixed;
}
</style>
"""
st.markdown(css, unsafe_allow_html=True)

# Function to fetch and process stock data
def get_stock_data(symbol, start_date, end_date):
    data = yf.download(symbol, start=start_date, end=end_date)
    data['Avg Price'] = data[['Open', 'Low', 'High', 'Adj Close']].mean(axis=1)
    data['Differenced'] = data['Avg Price'].diff()
    data.dropna(subset=['Differenced'], inplace=True)
    return data


# Function to fit SARIMAX model and make predictions
def sarimax_model(train, test, steps):
    model = SARIMAX(train, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))  # Seasonal order can be tuned
    fitted_model = model.fit(disp=False)
    predictions = fitted_model.forecast(steps=len(test))
    future_predictions = fitted_model.forecast(steps=steps)

    mae = mean_absolute_error(test, predictions)
    mse = mean_squared_error(test, predictions)
    rmse = np.sqrt(mse)

    return predictions, future_predictions, mae, mse, rmse


# Streamlit app
st.title('Stock Price Prediction with SARIMAX')

# Inputs
symbol = st.text_input('Stock Symbol', 'RELIANCE.NS')
start_date = st.date_input('Start Date', pd.to_datetime('2014-07-01'))
end_date = st.date_input('End Date', pd.to_datetime('2024-06-30'))
future_steps = st.number_input('Future Steps', min_value=1, max_value=100, value=30)

# Fetch and display stock data
data = get_stock_data(symbol, start_date, end_date)
if data.empty:
    st.error('No data fetched. Please check the stock symbol and date range.')
else:
    train_size = int(len(data) * 0.8)
    train = data['Avg Price'][:train_size]
    test = data['Avg Price'][train_size:]

    # Fit SARIMAX model and get predictions
    sarimax_predictions, sarimax_future, sarimax_mae, sarimax_mse, sarimax_rmse = sarimax_model(train, test,
                                                                                                future_steps)

    # Display evaluation metrics
    st.write(f"SARIMAX Model - MAE: {sarimax_mae}, MSE: {sarimax_mse}, RMSE: {sarimax_rmse}")

    # Generate future dates
    future_dates = pd.date_range(start=data.index[-1] + pd.Timedelta(days=1), periods=future_steps, freq='B')


    # Plot the results
    fig, ax = plt.subplots(figsize=(14, 7))
    ax.plot(data.index, data['Avg Price'], label='Historical Data')
    ax.plot(test.index, test, label='Test Data', color='blue')
    ax.plot(test.index, sarimax_predictions, label='SARIMAX Predictions', color='red')
    ax.plot(future_dates, sarimax_future, label='SARIMAX Future Predictions', color='orange')
    ax.legend()
    st.pyplot(fig)

    st.write('## Future Predictions')
    sm = pd.DataFrame({'future_dates':future_dates,'Avg Predicted Price':sarimax_future})
    st.write(sm.reset_index().drop(columns= ['index']))

    # Future Predictions
    fig, ax = plt.subplots(figsize=(14, 7))
    ax.plot(future_dates, sarimax_future, label='SARIMAX Future Predictions', color='cyan', linestyle='--')
    ax.legend()
    st.pyplot(fig)
# Out:
# 2024-08-15 06:20:39.198
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2024-08-15 06:20:39.211 Session state does not function when running a script without `streamlit run`
# [*********************100%%**********************]  1 of 1 completed
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# !pip install openpyxl
# !pip install streamlit
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: streamlit in /usr/local/lib/python3.10/dist-packages (1.37.1)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.4.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.1.4)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Requirement already satisfied: watchdog<5,>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.0.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2024.7.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)

# %%
import streamlit as st
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
from io import BytesIO

# Custom CSS for background image
css = """
<style>
body {
    background-image: url('data:download (3).jfif');
    background-size: cover;
    background-attachment: fixed;
}
</style>
"""
st.markdown(css, unsafe_allow_html=True)

def get_stock_data(symbol, start_date, end_date):
    data = yf.download(symbol, start=start_date, end=end_date)
    data['Avg Price'] = data[['Open', 'Low', 'High', 'Adj Close']].mean(axis=1)
    data['Differenced'] = data['Avg Price'].diff()
    data.dropna(subset=['Differenced'], inplace=True)
    return data

def sarimax_model(train, test, steps):
    model = SARIMAX(train, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
    fitted_model = model.fit(disp=False)
    predictions = fitted_model.forecast(steps=len(test))
    future_predictions = fitted_model.forecast(steps=steps)

    mae = mean_absolute_error(test, predictions)
    mse = mean_squared_error(test, predictions)
    rmse = np.sqrt(mse)

    return predictions, future_predictions, mae, mse, rmse

st.title('Stock Price Prediction with SARIMAX')

symbol = st.text_input('Stock Symbol', 'RELIANCE.NS')
start_date = st.date_input('Start Date', pd.to_datetime('2014-07-01'))
end_date = st.date_input('End Date', pd.to_datetime('2024-06-30'))
future_steps = st.number_input('Future Steps', min_value=1, max_value=100, value=30)

data = get_stock_data(symbol, start_date, end_date)
if data.empty:
    st.error('No data fetched. Please check the stock symbol and date range.')
else:
    st.sidebar.title('Navigation')
    section = st.sidebar.radio('Go to', ['Data Details', 'Visualizations', 'Predictions'])

    if section == 'Data Details':
        st.header('Data Details')
        st.write(data)
        st.write('## Summary Statistics')
        st.write(data.describe())

    elif section == 'Visualizations':
        st.header('Visualizations')

        st.subheader('Historical Average Price')
        fig, ax = plt.subplots(figsize=(14, 7))
        ax.plot(data.index, data['Avg Price'], label='Avg Price')
        ax.set_title('Historical Average Price')
        ax.set_xlabel('Date')
        ax.set_ylabel('Price')
        ax.legend()
        st.pyplot(fig)

    elif section == 'Predictions':
        st.header('Predictions')

        train_size = int(len(data) * 0.8)
        train = data['Avg Price'][:train_size]
        test = data['Avg Price'][train_size:]

        if st.button('Predict'):
            sarimax_predictions, sarimax_future, sarimax_mae, sarimax_mse, sarimax_rmse = sarimax_model(train, test, future_steps)
            st.write(f"SARIMAX Model - MAE: {sarimax_mae}, MSE: {sarimax_mse}, RMSE: {sarimax_rmse}")

            future_dates = pd.date_range(start=data.index[-1] + pd.Timedelta(days=1), periods=future_steps, freq='B')

            st.subheader('Prediction Results')
            fig, ax = plt.subplots(figsize=(14, 7))
            ax.plot(data.index, data['Avg Price'], label='Historical Data')
            ax.plot(test.index, test, label='Test Data', color='blue')
            ax.plot(test.index, sarimax_predictions, label='SARIMAX Predictions', color='red')
            ax.plot(future_dates, sarimax_future, label='SARIMAX Future Predictions', color='orange')
            ax.legend()
            st.pyplot(fig)

            st.subheader('Future Predictions')
            future_df = pd.DataFrame({'Date': future_dates, 'Predicted Avg Price': sarimax_future})
            st.write(future_df)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
! wget -q -O - ipv4.icanhazip.com
# Out:
# 35.245.161.84

# %%
# !streamlit run Stock.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.245.161.84:8501
#
# your url is: https://two-wombats-go.loca.lt
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
